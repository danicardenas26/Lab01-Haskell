-- %%
-- take 5 (map(*2)) [1..], significa que va a tomar 5 datos de una lista lista desde 1 y los va a duplicar, por lo que la lista  seria [1, 2, 3, 4, 5] y su 
-- duplicado seria [2, 4, 6, 8, 20]

-- %%
take 5 (map(*2) [1..])
-- Out:
-- [2,4,6,8,10]

-- %%
-- no produce una lista infinita debido a la lazy evaluation, si solo le piden 5 haskell unicamente genera esos 5

-- %%
-- 2. nos dan los arg x=(5+7), y=(4*3), x>10? => x = 12 => 12>10 True
-- y*2, y=12 => 12*2: 24
